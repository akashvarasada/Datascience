# %%
# Importing libraries
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport

# %%
#importing dataset
train = pd.read_excel(r'C:/Users/30016142/Profiling/Flight_data_BI.xlsx')

# %%
profile = ProfileReport(train)
profile.to_file("Flight_BI_Profiling1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
train1 = pd.read_excel(r'C:/Users/30016142/Profiling/05.Whether_Highland.xlsx')
profile1 = ProfileReport(train1)
profile1.to_file("Whether_highland_profiling1.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
