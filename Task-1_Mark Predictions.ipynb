# %% [markdown]
# # Akash Varasada GRIP intern Data Analytics

# %% [markdown]
# ### **Regression model to Students Marks Prediction based on hours of study**
# This assignment is a part of a GRIP internship June-2020

# %% [markdown]
# ## **Simple Linear Regression**
#
# In this regression task we will predict the percentage of marks that a student is expected to score based upon the number of hours they studied. This is a simple linear regression task as it involves just two variables.
#
# Linear Regression Formula =>
# Y = bx + c
#         where b is slope of the predicted line
#         c is intercept
# we will try to find best fit line through modelling

# %%
# Importing all libraries required in this notebook
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
df = pd.read_csv(r"E:/GRIP Internship/Tasks/Students Score Prediction/student_scores - student_scores.csv")

# %%
df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof
prof.to_file(output_file='EDA-Output-Electricity-Data.html')## sharing separate HTML file

# %%
prof.to_widgets()

# %%
##Finding null values in data
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
X = df.iloc[:, :-1].values  
y = df.iloc[:, 1].values

# %%
X
# Out:
# array([[2.5],
#        [5.1],
#        [3.2],
#        [8.5],
#        [3.5],
#        [1.5],
#        [9.2],
#        [5.5],
#        [8.3],
#        [2.7],
#        [7.7],
#        [5.9],
#        [4.5],
#        [3.3],
#        [1.1],
#        [8.9],
#        [2.5],
#        [1.9],
#        [6.1],
#        [7.4],
#        [2.7],
#        [4.8],
#        [3.8],
#        [6.9],
#        [7.8]])

# %%
y
# Out:
# array([21, 47, 27, 75, 30, 20, 88, 60, 81, 25, 85, 62, 41, 42, 17, 95, 30,
#        24, 67, 69, 30, 54, 35, 76, 86], dtype=int64)

# %%
from sklearn.model_selection import train_test_split  
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                            test_size=0.2, random_state=100)

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
b= regressor.coef_
print(b)
# Out:
# [9.83544438]

# %%
c=regressor.intercept_
print(c)
# Out:
# 1.9894231109746912

# %%
#making standard formula of Linear Regression
Ypred = b*X + c

# %%
Ypred
# Out:
# array([[26.57803407],
#        [52.15018946],
#        [33.46284514],
#        [85.59070036],
#        [36.41347845],
#        [16.74258969],
#        [92.47551143],
#        [56.08436722],
#        [83.62361149],
#        [28.54512294],
#        [77.72234486],
#        [60.01854497],
#        [46.24892283],
#        [34.44638957],
#        [12.80841193],
#        [89.52487812],
#        [26.57803407],
#        [20.67676744],
#        [61.98563385],
#        [74.77171154],
#        [28.54512294],
#        [49.19955615],
#        [39.36411177],
#        [69.85398935],
#        [78.7058893 ]])

# %%
# Plotting for the test data
plt.scatter(X, y)
plt.plot(X, Ypred);
plt.show()

# %%
y_pred = regressor.predict(X_test) # Predicting the scores
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.140342096254413

# %%
##Finding out model accuracy

print("Accuracy:",metrics.r2_score(y_test, y_pred))
# Out:
# Accuracy: 0.9050356232459791

# %% [markdown]
# ## Our model has great accuracy of 90%

# %% [markdown]
# now we will find student score based on reading hours input from us.

# %%
# You can also test with your own data
hours = input('student reading hours :' )
Predicted_score = b * float(hours) + c
print("No of Hours = {}".format(hours))
print("Predicted Score = {}".format(Predicted_score))
# Out:
# student reading hours :6.5
# No of Hours = 6.5
# Predicted Score = [65.9198116]

# %% [markdown]
# Thanks for watching guys!!
